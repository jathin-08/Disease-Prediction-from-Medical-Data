# %% [markdown]
# # Notebook 05: Breast Cancer Classification Modeling
#
# Trains SVM, Logistic Regression, Random Forest, and XGBoost on Breast Cancer dataset.

# %%
import sys
sys.path.append('../')
from src.preprocessor import load_processed_data
from src.models.xgboost_model import XGBoostModel

# %%
X_train, X_test, y_train, y_test = load_processed_data('breast_cancer')
xgb = XGBoostModel()
xgb.fit(X_train, y_train)
