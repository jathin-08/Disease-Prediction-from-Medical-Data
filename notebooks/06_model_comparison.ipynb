# %% [markdown]
# # Notebook 06: Model Comparison & Final Evaluation
#
# Compares accuracy, F1, and ROC curves across SVM, Logistic Regression, Random Forest, and XGBoost models for all three diagnostic conditions.

# %%
import sys
sys.path.append('../')
from src.evaluation.train import train_and_save_pipeline

# %%
# Train full pipeline and compare metrics
train_and_save_pipeline()
