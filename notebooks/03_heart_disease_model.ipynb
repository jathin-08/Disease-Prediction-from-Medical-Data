# %% [markdown]
# # Notebook 03: Heart Disease Classification Modeling
#
# Trains SVM, Logistic Regression, Random Forest, and XGBoost on Heart Disease, evaluations are stored and compared.

# %%
import sys
sys.path.append('../')
from src.preprocessor import load_processed_data
from src.models.svm_model import SVMModel

# %%
X_train, X_test, y_train, y_test = load_processed_data('heart_disease')
svm = SVMModel()
svm.fit(X_train, y_train)
