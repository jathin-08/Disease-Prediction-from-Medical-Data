# %% [markdown]
# # Notebook 04: Diabetes Classification Modeling
#
# Trains SVM, Logistic Regression, Random Forest, and XGBoost on Diabetes dataset.

# %%
import sys
sys.path.append('../')
from src.preprocessor import load_processed_data
from src.models.random_forest import RandomForestModel

# %%
X_train, X_test, y_train, y_test = load_processed_data('diabetes')
rf = RandomForestModel()
rf.fit(X_train, y_train)
