# %% [markdown]
# # Notebook 02: Preprocessing & Train-Test Splits
#
# This notebook covers loading raw data, cleaning, scaling numerical parameters using standard scaling, and generating test train splits.

# %%
import sys
sys.path.append('../')
from src.preprocessor import preprocess_and_split_all

# %%
# Preprocess, scale and split
preprocess_and_split_all()
