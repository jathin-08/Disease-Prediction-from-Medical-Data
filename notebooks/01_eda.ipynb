# %% [markdown]
# # Notebook 01: Exploratory Data Analysis (EDA)
#
# This notebook demonstrates exploratory data analysis on the three target diagnostic datasets:
# 1. Heart Disease (Cleveland clinic)
# 2. Diabetes (Pima Indian women)
# 3. Breast Cancer (Wisconsin Diagnostic)
#
# ### Objectives:
# - Check feature data types, missing values, and ranges
# - Plot class distribution balances
# - Investigate feature correlations with the target outcome variable

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sys
sys.path.append('../')
import config
from src.data_loader import get_raw_dataset

# %%
# Load dataset
df = get_raw_dataset('heart_disease')
df.head()

# %%
# Check class distributions
sns.countplot(x='target', data=df)
plt.title('Heart Disease Target Class Balance')
plt.show()
